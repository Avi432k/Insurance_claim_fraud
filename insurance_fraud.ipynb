# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/Users/avishandilya/Desktop/Data Analytics Project/insurance_dataset1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 46 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   row_num                      1000 non-null   int64
#  1   months_as_customer           1000 non-null   int64
#  2   months_bracket               1000 non-null   object
#  3   age                          1000 non-null   int64
#  4   age_bracket                  1000 non-null   object
#  5   policy_number                1000 non-null   int64
#  6   policy_bind_date             1000 non-null   object
#  7   policy_state                 1000 non-null   object
#  8   policy_csl                   1000 non-null   object
#  9   policy_deductable            1000 non-null   int64
#  10  policy_annual_premium        1000 non-null   float64
#  11  annual_premium_bracket       1000 non-null   object
#  12  umbrella_limit               1000 non-null   int64
# ...

# %%
df.describe()
# Out:
#            row_num  months_as_customer          age  policy_number  \
# count  1000.000000         1000.000000  1000.000000    1000.000000
# mean    500.500000          203.954000    38.948000  546238.648000
# std     288.819436          115.113174     9.140287  257063.005276
# min       1.000000            0.000000    19.000000  100804.000000
# 25%     250.750000          115.750000    32.000000  335980.250000
# 50%     500.500000          199.500000    38.000000  533135.000000
# 75%     750.250000          276.250000    44.000000  759099.750000
# max    1000.000000          479.000000    64.000000  999435.000000
#
#        policy_deductable  policy_annual_premium  umbrella_limit  \
# count        1000.000000            1000.000000    1.000000e+03
# mean         1136.000000            1256.406150    1.101000e+06
# std           611.864673             244.167395    2.297407e+06
# min           500.000000             433.330000   -1.000000e+06
# ...

# %%
df.head()
# Out:
#    row_num  months_as_customer months_bracket  age age_bracket  policy_number  \
# 0        1                 328        241-360   48       41-50         521585
# 1        2                 228        121-240   42       41-50         342868
# 2        3                 134        121-240   29       19-30         687698
# 3        4                 256        241-360   41       41-50         227811
# 4        5                 228        121-240   44       41-50         367455
#
#   policy_bind_date policy_state policy_csl  policy_deductable  ...  \
# 0       2014-10-17           OH    250/500               1000  ...
# 1       2006-06-27           IN    250/500               2000  ...
# 2       2000-09-06           OH    100/300               2000  ...
# 3       1990-05-25           IL    250/500               2000  ...
# 4       2014-06-06           IL   500/1000               1000  ...
#
#    police_report_available total_claim_amount  total_claim_amount_bracket  \
# ...

# %%
df.shape
# Out:
# (1000, 46)

# %%
df.columns
# Out:
# Index(['row_num', 'months_as_customer', 'months_bracket', 'age', 'age_bracket',
#        'policy_number', 'policy_bind_date', 'policy_state', 'policy_csl',
#        'policy_deductable', 'policy_annual_premium', 'annual_premium_bracket',
#        'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital_gains', 'capital_loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_city_state', 'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'witness_present', 'police_report_available',
#        'total_claim_amount', 'total_claim_amount_bracket', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make', 'auto_model',
# ...

# %%
print(df.isnull().sum())
# Out:
# row_num                          0
# months_as_customer               0
# months_bracket                   0
# age                              0
# age_bracket                      0
# policy_number                    0
# policy_bind_date                 0
# policy_state                     0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# annual_premium_bracket           0
# umbrella_limit                   0
# insured_zip                      0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_hobbies                  0
# insured_relationship             0
# capital_gains                    0
# capital_loss                     0
# incident_date                    0
# incident_type                    0
# collision_type                 178
# incident_severity                0
# authorities_contacted           91
# incident_state                   0
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.dtypes
# Out:
# row_num                          int64
# months_as_customer               int64
# months_bracket                  object
# age                              int64
# age_bracket                     object
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# annual_premium_bracket          object
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital_gains                    int64
# capital_loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# ...

# %%
df["collision_type"]
# Out:
# 0       Side Collision
# 1                  NaN
# 2       Rear Collision
# 3      Front Collision
# 4                  NaN
#             ...
# 995    Front Collision
# 996     Rear Collision
# 997     Side Collision
# 998     Rear Collision
# 999                NaN
# Name: collision_type, Length: 1000, dtype: object

# %%
print(df[["incident_type", "collision_type",]])
# Out:
#                 incident_type   collision_type
# 0    Single Vehicle Collision   Side Collision
# 1               Vehicle Theft              NaN
# 2     Multi-vehicle Collision   Rear Collision
# 3    Single Vehicle Collision  Front Collision
# 4               Vehicle Theft              NaN
# ..                        ...              ...
# 995  Single Vehicle Collision  Front Collision
# 996  Single Vehicle Collision   Rear Collision
# 997   Multi-vehicle Collision   Side Collision
# 998  Single Vehicle Collision   Rear Collision
# 999                Parked Car              NaN
#
# [1000 rows x 2 columns]

# %%
df['collision_type'].fillna('No Collision', inplace = True)

# %%
df['collision_type']
# Out:
# 0       Side Collision
# 1         No Collision
# 2       Rear Collision
# 3      Front Collision
# 4         No Collision
#             ...
# 995    Front Collision
# 996     Rear Collision
# 997     Side Collision
# 998     Rear Collision
# 999       No Collision
# Name: collision_type, Length: 1000, dtype: object

# %%
df['policy_bind_date'] = pd.to_datetime(df['policy_bind_date'])
df['incident_date'] = pd.to_datetime(df['incident_date'])

# %%
df.dtypes
# Out:
# row_num                                 int64
# months_as_customer                      int64
# months_bracket                         object
# age                                     int64
# age_bracket                            object
# policy_number                           int64
# policy_bind_date               datetime64[ns]
# policy_state                           object
# policy_csl                             object
# policy_deductable                       int64
# policy_annual_premium                 float64
# annual_premium_bracket                 object
# umbrella_limit                          int64
# insured_zip                             int64
# insured_sex                            object
# insured_education_level                object
# insured_occupation                     object
# insured_hobbies                        object
# insured_relationship                   object
# capital_gains                           int64
# ...

# %%
percent_fraud = (((df['fraud_reported'] == 'Yes').sum())/(len(df['fraud_reported']))*100)

# %%
percent_fraud
# Out:
# 24.7

# %%
from scipy.stats import chi2_contingency

# Create a contingency table
contingency_table = pd.crosstab(df["incident_severity"], df["fraud_reported"])

# Perform the Chi-Square test
chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)

# Display results
chi2_stat, p_value, dof
# Out:
# (264.2373497806052, 5.447033547673786e-57, 3)

# %%
df.to_csv(r'/Users/avishandilya/Desktop/Data Analytics Project/insurance_dataset2.csv')

# %%
df['collision_type']
# Out:
# 0       Side Collision
# 1         No Collision
# 2       Rear Collision
# 3      Front Collision
# 4         No Collision
#             ...
# 995    Front Collision
# 996     Rear Collision
# 997     Side Collision
# 998     Rear Collision
# 999       No Collision
# Name: collision_type, Length: 1000, dtype: object
